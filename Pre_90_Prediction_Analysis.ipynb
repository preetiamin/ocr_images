# %%
import pandas as pd
from helper import *
import time
import ocr

# %% [markdown]
# ### This notebook processes raw OCR Text output from post 1990 images and analyzes accuracy

# %% [markdown]
# Load raw data with OCR text/barcodes, labeled data, nlp model and regex model

# %%
# Load raw data
df=pd.read_excel('Pre_Raw_Data.xlsx')
mod = handwritten_model()
df_labels = pd.read_excel('specimens_pre_1900.xlsx')
pd.set_option('mode.chained_assignment', None)

# %% [markdown]
# Make predictions using the model

# %%
# Retrieve entities using nlp (for state, species) and regex (for date, barcode)
starttime = time.time()
df['State'] = df['OCRText'].dropna().apply(mod.predict_state)
df['Species'] = df['OCRText'].dropna().apply(mod.predict_species)
df['Year'] = df['OCRText'].dropna().apply(mod.find_year)
df['Barcode'] = df['OCRText'].dropna().apply(ocr.find_barcode)
print('Total time: {:.1f} secs'.format(time.time()-starttime))
# Out:
# Total time: 39.2 secs

# %% [markdown]
# Load labels from labeled data file

# %%
# Get actual labels
starttime = time.time()
df['Act_Barcode'] = df_labels['Barcode']
df['Act_State'] = df_labels['ProvinceState']
df['Act_Date'] = df_labels['DateFrom']
print('Total time: {:.1f} secs'.format(time.time()-starttime))
# Out:
# Total time: 0.0 secs

# %%
df
# Out:
#       Unnamed: 0                                            OCRText     State  \
# 0              1  THE NEW YORK BOTANICAL GARDEN copyright reserv...  Colorado
# 1              2  THE NEW YORK BOTANICAL GARDEN copyright reserv...  Colorado
# 2              3  THE NEW YORK BOTANICAL GARDEN copyright reserv...  Colorado
# 3              4  THE NEW YORK BOTANICAL GARDEN copyright reserv...  Colorado
# 4              5  THE NEW YORK BOTANICAL GARDEN copyright reserv...  Colorado
# ...          ...                                                ...       ...
# 4995        4996  THE NEW YORK BOTANICAL GARDEN copyright reserv...      None
# 4996        4997  CARDEN THE NEW YORK BOTANICAL GARDEN copyright...      None
# 4997        4998  THE NEW YORK BOTANICAL GARDEN copyright reserv...      None
# 4998        4999  THE NEW YORK BOTANICAL GARDEN copyright reserv...      None
# 4999        5000  NEW YORK THE NEW YORK BOTANICAL GARDEN copyrig...      None
#
#                       Species    Year    Barcode  Act_Barcode   Act_County  \
# 0        Eriogonum corymbosum  1966.0  3103066.0      3103066    Montezuma
# 1                  A. globosa  1962.0  2739619.0      2739619          NaN
# 2                        None  1965.0  3097297.0      3097297      Chaffee
# 3     Pulialiller ludoviciana     NaN  2740422.0      2740422      Larimer
# 4                        None  1945.0  2742023.0      2742023          NaN
# ...                       ...     ...        ...          ...          ...
# 4995                     None  1898.0  1894858.0      1894858  Clear Creek
# 4996         mermeria exicana  1896.0  1900752.0      1900752          NaN
# 4997     Chrysothamnus parryi  1926.0  2040491.0      2040491         Lake
# 4998                     None  1896.0  2883277.0      2883277          NaN
# 4999                     None  4818.0  2874865.0      2874865        Ouray
#
#      Act_State    Act_Date   Act_Collector
# 0     Colorado  1898-06-29  C. S. Crandall
# 1     Colorado  1894-07-09  C. S. Crandall
# 2     Colorado  1897-08-19  C. S. Crandall
# 3     Colorado  1893-05-12  C. S. Crandall
# 4     Colorado  1895-08-01  C. S. Crandall
# ...        ...         ...             ...
# 4995  Colorado  1895-08-27     C. L. Shear
# 4996  Colorado  1896-07-20     C. L. Shear
# 4997  Colorado  1896-08-20     C. L. Shear
# 4998  Colorado  1896-08-24     C. L. Shear
# 4999  Colorado  1897-07-24     C. L. Shear
#
# [5000 rows x 11 columns]

# %% [markdown]
# Change dates to date formats

# %%
df['Act_Date'] = pd.to_datetime(df['Act_Date'], errors='coerce')
df['Act_Year'] = df['Act_Date'].dropna().apply(lambda x: x.year).astype('int64')

# %%
df
# Out:
#       Unnamed: 0                                            OCRText     State  \
# 0              1  THE NEW YORK BOTANICAL GARDEN copyright reserv...  Colorado
# 1              2  THE NEW YORK BOTANICAL GARDEN copyright reserv...  Colorado
# 2              3  THE NEW YORK BOTANICAL GARDEN copyright reserv...  Colorado
# 3              4  THE NEW YORK BOTANICAL GARDEN copyright reserv...  Colorado
# 4              5  THE NEW YORK BOTANICAL GARDEN copyright reserv...  Colorado
# ...          ...                                                ...       ...
# 4995        4996  THE NEW YORK BOTANICAL GARDEN copyright reserv...      None
# 4996        4997  CARDEN THE NEW YORK BOTANICAL GARDEN copyright...      None
# 4997        4998  THE NEW YORK BOTANICAL GARDEN copyright reserv...      None
# 4998        4999  THE NEW YORK BOTANICAL GARDEN copyright reserv...      None
# 4999        5000  NEW YORK THE NEW YORK BOTANICAL GARDEN copyrig...      None
#
#                       Species    Year    Barcode  Act_Barcode   Act_County  \
# 0        Eriogonum corymbosum  1966.0  3103066.0      3103066    Montezuma
# 1                  A. globosa  1962.0  2739619.0      2739619          NaN
# 2                        None  1965.0  3097297.0      3097297      Chaffee
# 3     Pulialiller ludoviciana     NaN  2740422.0      2740422      Larimer
# 4                        None  1945.0  2742023.0      2742023          NaN
# ...                       ...     ...        ...          ...          ...
# 4995                     None  1898.0  1894858.0      1894858  Clear Creek
# 4996         mermeria exicana  1896.0  1900752.0      1900752          NaN
# 4997     Chrysothamnus parryi  1926.0  2040491.0      2040491         Lake
# 4998                     None  1896.0  2883277.0      2883277          NaN
# 4999                     None  4818.0  2874865.0      2874865        Ouray
#
#      Act_State   Act_Date   Act_Collector  Act_Year
# 0     Colorado 1898-06-29  C. S. Crandall    1898.0
# 1     Colorado 1894-07-09  C. S. Crandall    1894.0
# 2     Colorado 1897-08-19  C. S. Crandall    1897.0
# 3     Colorado 1893-05-12  C. S. Crandall    1893.0
# 4     Colorado 1895-08-01  C. S. Crandall    1895.0
# ...        ...        ...             ...       ...
# 4995  Colorado 1895-08-27     C. L. Shear    1895.0
# 4996  Colorado 1896-07-20     C. L. Shear    1896.0
# 4997  Colorado 1896-08-20     C. L. Shear    1896.0
# 4998  Colorado 1896-08-24     C. L. Shear    1896.0
# 4999  Colorado 1897-07-24     C. L. Shear    1897.0
#
# [5000 rows x 12 columns]

# %%
def calculate_accuracy(df):
    acc_state = 100 * (df[df['State']==df['Act_State']]).shape[0]/df['OCRText'].count()
    acc_date = 100 * (df[df['Year']==df['Act_Year']]).shape[0]/df['OCRText'].count()
    acc_barcode = 100 * (df[df['Barcode']==df['Act_Barcode']]).shape[0]/df['OCRText'].count()
    
    perc_species = 100 * df['Species'].count()/df['OCRText'].count()

    print('Accuracy ======> State: {:.1f}%, Year: {:.1f}%, Species predicted: {:.1f}%'.format(
        acc_state, acc_date, perc_species))
    print('Barcode accuracy ======> {:.1f}%'.format(acc_barcode))

# %% [markdown]
# Predict accuracy

# %%
calculate_accuracy(df)
# Out:
# Accuracy ======> State: 89.3%, Year: 23.2%, Species predicted: 59.1%
# Barcode accuracy ======> 88.8%

# %% [markdown]
# Save files

# %%
df.to_csv('Pre_90_Analysis.csv')
